# %% [markdown]
# # Download the dataset

# %%
import autogluon as ag
filename = ag.download('https://autogluon.s3.amazonaws.com/datasets/shopee-iet.zip')
ag.unzip(filename)

# %% [markdown]
# # Upload data to S3

# %%
import sagemaker as sage
sess = sage.Session()
prefix = 'DEMO-autogluon-example'
data_location = sess.upload_data('./data', key_prefix=prefix)

# %%
# if you have already uploaed, using:
data_location='s3://sagemaker-us-west-2-097403188315/DEMO-autogluon-example'

# %% [markdown]
# # Submit SageMaker Training Job

# %%
import boto3

client = boto3.client('sts')
account = client.get_caller_identity()['Account']

my_session = boto3.session.Session()
region = my_session.region_name

algorithm_name = 'autogluon-example-gpu-py36-cu100'

ecr_image = '{}.dkr.ecr.{}.amazonaws.com/{}:latest'.format(account, region, algorithm_name)

print(ecr_image)
# Out:
# Found credentials in shared credentials file: ~/.aws/credentials
# 097403188315.dkr.ecr.us-west-2.amazonaws.com/autogluon-example-gpu-py36-cu100:latest

# %%
from sagemaker.estimator import Estimator

instance_type = 'ml.p3.2xlarge'
# change it to your own account SageMaker role arn
role = "arn:aws:iam::097403188315:role/service-role/AmazonSageMaker-ExecutionRole-20200106T104790"
hyperparameters = {'epochs': 5}

estimator = Estimator(role=role,
                      train_instance_count=2,
                      train_instance_type=instance_type,
                      image_name=ecr_image,
                      hyperparameters=hyperparameters)

estimator.fit(data_location)
# Out:
# Found credentials in shared credentials file: ~/.aws/credentials
# Creating training-job with name: autogluon-example-gpu-py36-cu100-2020-03-31-19-59-24-327
# 2020-03-31 19:59:25 Starting - Starting the training job...
# 2020-03-31 19:59:27 Starting - Launching requested ML instances......
# 2020-03-31 20:00:56 Starting - Preparing the instances for training.........
# 2020-03-31 20:02:23 Downloading - Downloading input data
# 2020-03-31 20:02:23 Training - Downloading the training image...........2020-03-31 20:04:07,719 sagemaker-containers INFO     Imported framework sagemaker_mxnet_container.training
# 2020-03-31 20:04:07,799 sagemaker_mxnet_container.training INFO     MXNet training environment: {'SM_HOSTS': '["algo-1","algo-2"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"epochs":5}', 'SM_USER_ENTRY_POINT': 'image_classification.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'image_classification', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_mxnet_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '64', 'SM_NUM_GPUS': '8', 'SM_MODEL_DIR': '/opt/ml/model', 'SM_MODULE_DIR': '/opt/ml/code', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"epochs":5},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"autogluon-example-gpu-py36-cu100-2020-03-31-19-59-24-327","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"image_classification","network_interface_name":"eth0","num_cpus":64,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"image_classification.py"}', 'SM_USER_ARGS': '["--epochs","5"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_EPOCHS': '5'}
# 2020-03-31 20:04:07,800 sagemaker-containers INFO     Module image_classification does not provide a setup.py.
# Generating setup.py
# 2020-03-31 20:04:07,800 sagemaker-containers INFO     Generating setup.cfg
# 2020-03-31 20:04:07,801 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-03-31 20:04:07,801 sagemaker-containers INFO     Installing module with the following command:
# /usr/local/bin/python3.6 -m pip install -U .
# Processing /opt/ml/code
# Installing collected packages: image-classification
#     Running setup.py install for image-classification: started
#     Running setup.py install for image-classification: finished with status 'done'
# Successfully installed image-classification-1.0.0
# 2020-03-31 20:04:10,235 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_mxnet_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "epochs": 5
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "autogluon-example-gpu-py36-cu100-2020-03-31-19-59-24-327",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "image_classification",
#     "network_interface_name": "eth0",
#     "num_cpus": 64,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "image_classification.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":5}
# SM_USER_ENTRY_POINT=image_classification.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=image_classification
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_mxnet_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=64
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"epochs":5},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"autogluon-example-gpu-py36-cu100-2020-03-31-19-59-24-327","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"image_classification","network_interface_name":"eth0","num_cpus":64,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"image_classification.py"}
# SM_USER_ARGS=["--epochs","5"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_EPOCHS=5
# PYTHONPATH=/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages:/autogluon
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.6 -m image_classification --epochs 5
#
#
# 2020-03-31 20:04:10,291 sagemaker-containers INFO     Imported framework sagemaker_mxnet_container.training
# 2020-03-31 20:04:10,371 sagemaker_mxnet_container.training INFO     MXNet training environment: {'SM_HOSTS': '["algo-1","algo-2"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"epochs":5}', 'SM_USER_ENTRY_POINT': 'image_classification.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-2', 'SM_MODULE_NAME': 'image_classification', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_mxnet_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '64', 'SM_NUM_GPUS': '8', 'SM_MODEL_DIR': '/opt/ml/model', 'SM_MODULE_DIR': '/opt/ml/code', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-2","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"epochs":5},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"autogluon-example-gpu-py36-cu100-2020-03-31-19-59-24-327","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"image_classification","network_interface_name":"eth0","num_cpus":64,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"image_classification.py"}', 'SM_USER_ARGS': '["--epochs","5"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_EPOCHS': '5'}
# 2020-03-31 20:04:10,372 sagemaker-containers INFO     Module image_classification does not provide a setup.py.
# Generating setup.py
# 2020-03-31 20:04:10,372 sagemaker-containers INFO     Generating setup.cfg
# 2020-03-31 20:04:10,372 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-03-31 20:04:10,373 sagemaker-containers INFO     Installing module with the following command:
# /usr/local/bin/python3.6 -m pip install -U .
# Processing /opt/ml/code
# Installing collected packages: image-classification
#     Running setup.py install for image-classification: started
#     Running setup.py install for image-classification: finished with status 'done'
# Successfully installed image-classification-1.0.0
# 2020-03-31 20:04:12,848 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_mxnet_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "epochs": 5
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "autogluon-example-gpu-py36-cu100-2020-03-31-19-59-24-327",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "image_classification",
#     "network_interface_name": "eth0",
#     "num_cpus": 64,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "image_classification.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":5}
# SM_USER_ENTRY_POINT=image_classification.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=image_classification
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_mxnet_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=64
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-2","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"epochs":5},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"autogluon-example-gpu-py36-cu100-2020-03-31-19-59-24-327","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"image_classification","network_interface_name":"eth0","num_cpus":64,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"image_classification.py"}
# SM_USER_ARGS=["--epochs","5"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_EPOCHS=5
# PYTHONPATH=/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages:/autogluon
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.6 -m image_classification --epochs 5
#
#
# /usr/local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# args Namespace(current_host='algo-1', data_dir='/opt/ml/input/data/training', epochs=5, hosts=['algo-1', 'algo-2'], model_dir='/opt/ml/model', num_gpus=8)
# hosts that aren't SSHable yet: %s ['algo-1', 'algo-2']
# testing connection to host %s algo-1
# can't connect to host %s algo-1
# testing connection to host %s algo-2
# can't connect to host %s algo-2
# hosts that aren't SSHable yet: %s ['algo-1', 'algo-2']
# testing connection to host %s algo-1
# can connect to host %s algo-1
# hosts that aren't SSHable yet: %s ['algo-2']
# testing connection to host %s algo-2
# can't connect to host %s algo-2
# hosts that aren't SSHable yet: %s ['algo-2']
# testing connection to host %s algo-2
# can connect to host %s algo-2
# 2020-03-31 20:04:09 Training - Training image download completed. Training in progress./usr/local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# args Namespace(current_host='algo-2', data_dir='/opt/ml/input/data/training', epochs=5, hosts=['algo-1', 'algo-2'], model_dir='/opt/ml/model', num_gpus=8)
# /usr/local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:39: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   m.add_string(self.Q_C.public_numbers().encode_point())
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:96: CryptographyDeprecationWarning: Support for unsafe construction of public numbers from encoded data will be removed in a future version. Please use EllipticCurvePublicKey.from_encoded_point
#   self.curve, Q_S_bytes
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:111: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   hm.add_string(self.Q_C.public_numbers().encode_point())
# [ worker algo-2 ] : dask-worker algo-2:8702 --no-nanny  --host algo-2
# [ #033scheduler algo-2:8702#033 ] : dask-scheduler --port 8702
# [ #033scheduler algo-2:8702#033 ] : Warning: Your terminal does not set locales.
# [ #033scheduler algo-2:8702#033 ] :
# [ #033scheduler algo-2:8702#033 ] : If you use unicode text inputs for command line options then this may cause
# [ #033scheduler algo-2:8702#033 ] : undesired behavior.  This is rare.
# [ #033scheduler algo-2:8702#033 ] :
# [ #033scheduler algo-2:8702#033 ] : If you don't use unicode characters in command line options then you can safely
# [ #033scheduler algo-2:8702#033 ] : ignore this message.  This is the common case.
# [ #033scheduler algo-2:8702#033 ] :
# [ #033scheduler algo-2:8702#033 ] : You can support unicode inputs by specifying encoding environment variables,
# [ #033scheduler algo-2:8702#033 ] : though exact solutions may depend on your system:
# [ #033scheduler algo-2:8702#033 ] :
# [ #033scheduler algo-2:8702#033 ] :     $ export LC_ALL=C.UTF-8
# [ #033scheduler algo-2:8702#033 ] :     $ export LANG=C.UTF-8
# [ #033scheduler algo-2:8702#033 ] :
# [ #033scheduler algo-2:8702#033 ] : For more information see: http://click.pocoo.org/5/python3/
# [ #033scheduler algo-2:8702#033 ] :
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - -----------------------------------------------
# [ worker algo-2 ] : Warning: Your terminal does not set locales.
# [ worker algo-2 ] :
# [ worker algo-2 ] : If you use unicode text inputs for command line options then this may cause
# [ worker algo-2 ] : undesired behavior.  This is rare.
# [ worker algo-2 ] :
# [ worker algo-2 ] : If you don't use unicode characters in command line options then you can safely
# [ worker algo-2 ] : ignore this message.  This is the common case.
# [ worker algo-2 ] :
# [ worker algo-2 ] : You can support unicode inputs by specifying encoding environment variables,
# [ worker algo-2 ] : though exact solutions may depend on your system:
# [ worker algo-2 ] :
# [ worker algo-2 ] :     $ export LC_ALL=C.UTF-8
# [ worker algo-2 ] :     $ export LANG=C.UTF-8
# [ worker algo-2 ] :
# [ worker algo-2 ] : For more information see: http://click.pocoo.org/5/python3/
# [ worker algo-2 ] :
# [ #033scheduler algo-2:8702#033 ] : autogluon.dashboard.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: pip install jupyter-server-proxy
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - Local Directory:    /tmp/scheduler-mm0m63i8
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - -----------------------------------------------
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - Clear task state
# [ #033scheduler algo-2:8702#033 ] : /usr/local/lib/python3.6/site-packages/distributed/dashboard/core.py:72: UserWarning:
# [ #033scheduler algo-2:8702#033 ] : Port 8787 is already in use.
# [ #033scheduler algo-2:8702#033 ] : Perhaps you already have a cluster running?
# [ #033scheduler algo-2:8702#033 ] : Hosting the diagnostics dashboard on a random port instead.
# [ #033scheduler algo-2:8702#033 ] :   warnings.warn("\n" + msg)
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO -   Scheduler at:   tcp://10.0.153.224:8702
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO -   dashboard at:                    :36267
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - Register tcp://10.0.153.224:33767
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - Starting worker compute stream, tcp://10.0.153.224:33767
# [ #033scheduler algo-2:8702#033 ] : autogluon.core - INFO - Starting established connection
# [ worker algo-2 ] : autogluon.dashboard.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: pip install jupyter-server-proxy
# [ worker algo-2 ] : autogluon.worker - INFO -       Start worker at:   tcp://10.0.153.224:33767
# [ worker algo-2 ] : autogluon.worker - INFO -          Listening to:   tcp://10.0.153.224:33767
# [ worker algo-2 ] : autogluon.worker - INFO -          dashboard at:         10.0.153.224:39935
# [ worker algo-2 ] : autogluon.worker - INFO - Waiting to connect to:          tcp://algo-2:8702
# [ worker algo-2 ] : autogluon.worker - INFO - -------------------------------------------------
# [ worker algo-2 ] : autogluon.worker - INFO -               Threads:                         64
# [ worker algo-2 ] : autogluon.worker - INFO -                Memory:                  510.24 GB
# [ worker algo-2 ] : autogluon.worker - INFO -       Local Directory:      /root/worker-p1mwtkld
# [ worker algo-2 ] : autogluon.worker - INFO - -------------------------------------------------
# [ worker algo-2 ] : autogluon.worker - INFO -         Registered to:          tcp://algo-2:8702
# [ worker algo-2 ] : autogluon.worker - INFO - -------------------------------------------------
# [ worker algo-2 ] : autogluon.core - INFO - Starting established connection
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - Receive client connection: Remote-d4c16cb4-738a-11ea-8058-0283bac60d3e
# [ #033scheduler algo-2:8702#033 ] : autogluon.core - INFO - Starting established connection
# [ worker algo-2 ] : /usr/local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
# [ worker algo-2 ] :   warnings.warn(message, FutureWarning)
# scheduler: FIFOScheduler(
# DistributedResourceManager{
# (Remote: Remote REMOTE_ID: 0,
# #011<Remote: 'inproc://10.0.188.4/88/1' processes=1 threads=64, memory=510.24 GB>, Resource: NodeResourceManager(64 CPUs, 8 GPUs))
# (Remote: Remote REMOTE_ID: 1,
# #011<Remote: 'tcp://10.0.153.224:8702' processes=1 threads=64, memory=510.24 GB>, Resource: NodeResourceManager(64 CPUs, 8 GPUs))
# })
#
# Starting Experiments
# Num of Finished Tasks is 0
# Num of Pending Tasks is 2
# #015  0%|          | 0/2 [00:00<?, ?it/s]#015 50%|█████     | 1/2 [00:00<00:00,  5.85it/s]#015100%|██████████| 2/2 [00:00<00:00,  7.81it/s]
# {'dataset': <autogluon.task.image_classification.dataset.NativeImageFolderDataset object at 0x7ff4b7cbb358>, 'net': 'ResNet50_v1b', 'optimizer': <autogluon.core.optimizer.NAG object at 0x7ff4b7cbb390>, 'loss': SoftmaxCrossEntropyLoss(batch_axis=0, w=None), 'metric': 'accuracy', 'num_gpus': 1, 'split_ratio': 0.8, 'batch_size': 64, 'input_size': 224, 'epochs': 5, 'final_fit_epochs': 5, 'verbose': True, 'num_workers': 60, 'hybridize': True, 'final_fit': False, 'tricks': Dict{'last_gamma': False, 'use_pretrained': True, 'use_se': False, 'mixup': False, 'mixup_alpha': 0.2, 'mixup_off_epoch': 0, 'label_smoothing': False, 'no_wd': False, 'teacher_name': None, 'temperature': 20.0, 'hard_weight': 0.5, 'batch_norm': False, 'use_gn': False}, 'lr_config': Dict{'lr_mode': 'cosine', 'lr_decay': 0.1, 'lr_decay_period': 0, 'lr_decay_epoch': '40,80', 'warmup_lr': 0.0, 'warmup_epochs': 0}, 'task_id': 0}
# Model file not found. Downloading.
# Downloading /root/.mxnet/models/resnet50_v1b-0ecdba34.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/resnet50_v1b-0ecdba34.zip...
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - Receive client connection: Client-d658d6d2-738a-11ea-8132-0298a6364178
# [ #033scheduler algo-2:8702#033 ] : autogluon.core - INFO - Starting established connection
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - Receive client connection: Client-d659d998-738a-11ea-8132-0298a6364178
# [ #033scheduler algo-2:8702#033 ] : autogluon.core - INFO - Starting established connection
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - Receive client connection: Client-d65acbee-738a-11ea-8132-0298a6364178
# [ #033scheduler algo-2:8702#033 ] : autogluon.core - INFO - Starting established connection
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - Receive client connection: Client-d65bfa50-738a-11ea-8132-0298a6364178
# [ #033scheduler algo-2:8702#033 ] : autogluon.core - INFO - Starting established connection
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - Receive client connection: Client-d65cf168-738a-11ea-8132-0298a6364178
# [ #033scheduler algo-2:8702#033 ] : autogluon.core - INFO - Starting established connection
# [ #033scheduler algo-2:8702#033 ] : autogluon.scheduler - INFO - Receive client connection: Client-d65e1b2c-738a-11ea-8132-0298a6364178
# [ #033scheduler algo-2:8702#033 ] : autogluon.core - INFO - Starting established connection
# [ worker algo-2 ] : {'dataset': <autogluon.task.image_classification.dataset.NativeImageFolderDataset object at 0x7f0bec535668>, 'net': 'ResNet50_v1b', 'optimizer': <autogluon.core.optimizer.NAG object at 0x7f0bec5356a0>, 'loss': SoftmaxCrossEntropyLoss(batch_axis=0, w=None), 'metric': 'accuracy', 'num_gpus': 1, 'split_ratio': 0.8, 'batch_size': 64, 'input_size': 224, 'epochs': 5, 'final_fit_epochs': 5, 'verbose': True, 'num_workers': 60, 'hybridize': True, 'final_fit': False, 'tricks': Dict{'last_gamma': False, 'use_pretrained': True, 'use_se': False, 'mixup': False, 'mixup_alpha': 0.2, 'mixup_off_epoch': 0, 'label_smoothing': False, 'no_wd': False, 'teacher_name': None, 'temperature': 20.0, 'hard_weight': 0.5, 'batch_norm': False, 'use_gn': False}, 'lr_config': Dict{'lr_mode': 'cosine', 'lr_decay': 0.1, 'lr_decay_period': 0, 'lr_decay_epoch': '40,80', 'warmup_lr': 0.0, 'warmup_epochs': 0}, 'task_id': 1}
# [ worker algo-2 ] : Model file not found. Downloading.
# [ worker algo-2 ] : Downloading /root/.mxnet/models/resnet50_v1b-0ecdba34.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/resnet50_v1b-0ecdba34.zip...
# #015  0%|          | 0/55344 [00:00<?, ?KB/s]#015  8%|▊         | 4187/55344 [00:00<00:01, 41867.84KB/s]#015 17%|█▋        | 9633/55344 [00:00<00:01, 44987.31KB/s]#015 27%|██▋       | 15127/55344 [00:00<00:00, 47566.61KB/s]#015 37%|███▋      | 20753/55344 [00:00<00:00, 49877.09KB/s]#015 48%|████▊     | 26426/55344 [00:00<00:00, 51749.16KB/s]#015 58%|█████▊    | 32154/55344 [00:00<00:00, 53291.08KB/s]#015 68%|██████▊   | 37889/55344 [00:00<00:00, 54446.25KB/s]#015 79%|███████▉  | 43647/55344 [00:00<00:00, 55348.27KB/s]#015 89%|████████▉ | 49291/55344 [00:00<00:00, 55669.10KB/s]#015 99%|█████████▉| 54962/55344 [00:01<00:00, 55977.20KB/s]#015100%|██████████| 55344/55344 [00:01<00:00, 54926.76KB/s]
# [ worker algo-2 ] : #015  0%|                                                 | 0/55344 [00:00<?, ?KB/s]#015  6%|##1                                | 3387/55344 [00:00<00:01, 33869.55KB/s]#015 16%|#####5                             | 8775/55344 [00:00<00:01, 38116.34KB/s]#015 26%|########7                         | 14262/55344 [00:00<00:00, 41957.05KB/s]#015 36%|############                      | 19688/55344 [00:00<00:00, 45019.11KB/s]#015 46%|###############5                  | 25285/55344 [00:00<00:00, 47824.31KB/s]#015 66%|######################4           | 36531/55344 [00:00<00:00, 51740.76KB/s]#015 76%|#########################8        | 42080/55344 [00:00<00:00, 52810.42KB/s]#015 86%|#############################2    | 47593/55344 [00:00<00:00, 53484.55KB/s]#015 96%|################################6 | 53165/55344 [00:01<00:00, 54135.31KB/s]#015100%|##################################| 55344/55344 [00:01<00:00, 53324.75KB/s]
# #015  0%|          | 0/5 [00:00<?, ?it/s]#015[Epoch 1] training: accuracy=0.308:   0%|          | 0/5 [00:06<?, ?it/s]#015[Epoch 1] Validation: 0.400:   0%|          | 0/5 [00:07<?, ?it/s]       #015[Epoch 1] Validation: 0.400:  20%|██        | 1/5 [00:07<00:29,  7.25s/it]#015[Epoch 2] training: accuracy=0.421:  20%|██        | 1/5 [00:13<00:29,  7.25s/it]#015[Epoch 2] Validation: 0.456:  20%|██        | 1/5 [00:14<00:29,  7.25s/it]       #015[Epoch 2] Validation: 0.456:  40%|████      | 2/5 [00:14<00:21,  7.27s/it]#015[Epoch 3] training: accuracy=0.487:  40%|████      | 2/5 [00:20<00:21,  7.27s/it]#015[Epoch 3] Validation: 0.562:  40%|████      | 2/5 [00:21<00:21,  7.27s/it]       #015[Epoch 3] Validation: 0.562:  60%|██████    | 3/5 [00:21<00:14,  7.29s/it]#015[Epoch 4] training: accuracy=0.529:  60%|██████    | 3/5 [00:27<00:14,  7.29s/it]#015[Epoch 4] Validation: 0.512:  60%|██████    | 3/5 [00:29<00:14,  7.29s/it]       #015[Epoch 4] Validation: 0.512:  80%|████████  | 4/5 [00:29<00:07,  7.29s/it]#015[Epoch 5] training: accuracy=0.530:  80%|████████  | 4/5 [00:35<00:07,  7.29s/it]#015[Epoch 5] Validation: 0.519:  80%|████████  | 4/5 [00:36<00:07,  7.29s/it]       #015[Epoch 5] Validation: 0.519: 100%|██████████| 5/5 [00:36<00:00,  7.29s/it]#015[Epoch 5] Validation: 0.519: 100%|██████████| 5/5 [00:36<00:00,  7.30s/it]
# Finished Task with config: {'net.choice': 0, 'optimizer.learning_rate': 0.0031622777, 'optimizer.wd': 0.0003162278} and reward: 0.51875
# Finished Task with config: {'net.choice': 0, 'optimizer.learning_rate': 0.006253031247648153, 'optimizer.wd': 0.0005124621591189704} and reward: 0.65625
# {'dataset': <autogluon.task.image_classification.dataset.NativeImageFolderDataset object at 0x7ff4b56f6630>, 'net': 'ResNet50_v1b', 'optimizer': <autogluon.core.optimizer.NAG object at 0x7ff4b56f6668>, 'loss': SoftmaxCrossEntropyLoss(batch_axis=0, w=None), 'metric': 'accuracy', 'num_gpus': 1, 'split_ratio': 0.8, 'batch_size': 64, 'input_size': 224, 'epochs': 5, 'final_fit_epochs': 5, 'verbose': True, 'num_workers': 60, 'hybridize': True, 'final_fit': True, 'tricks': Dict{'last_gamma': False, 'use_pretrained': True, 'use_se': False, 'mixup': False, 'mixup_alpha': 0.2, 'mixup_off_epoch': 0, 'label_smoothing': False, 'no_wd': False, 'teacher_name': None, 'temperature': 20.0, 'hard_weight': 0.5, 'batch_norm': False, 'use_gn': False}, 'lr_config': Dict{'lr_mode': 'cosine', 'lr_decay': 0.1, 'lr_decay_period': 0, 'lr_decay_epoch': '40,80', 'warmup_lr': 0.0, 'warmup_epochs': 0}, 'task_id': 2}
# [ worker algo-2 ] : #015[Epoch 5] Validation: 0.656:  80%|############8   | 4/5 [00:35<00:07,  7.19s/it]#015[Epoch 5] Validation: 0.656: 100%|################| 5/5 [00:35<00:00,  7.18s/it]#015[Epoch 5] Validation: 0.656: 100%|################| 5/5 [00:35<00:00,  7.17s/it]
# #015  0%|          | 0/5 [00:00<?, ?it/s]#015[Epoch 1] training: accuracy=0.324:   0%|          | 0/5 [00:07<?, ?it/s]#015[Epoch 1] training: accuracy=0.324:  20%|██        | 1/5 [00:07<00:28,  7.21s/it]#015[Epoch 2] training: accuracy=0.446:  20%|██        | 1/5 [00:14<00:28,  7.21s/it]#015[Epoch 2] training: accuracy=0.446:  40%|████      | 2/5 [00:14<00:21,  7.20s/it]#015[Epoch 3] training: accuracy=0.520:  40%|████      | 2/5 [00:21<00:21,  7.20s/it]#015[Epoch 3] training: accuracy=0.520:  60%|██████    | 3/5 [00:21<00:14,  7.20s/it]#015[Epoch 4] training: accuracy=0.563:  60%|██████    | 3/5 [00:28<00:14,  7.20s/it]#015[Epoch 4] training: accuracy=0.563:  80%|████████  | 4/5 [00:28<00:07,  7.17s/it]#015[Epoch 5] training: accuracy=0.592:  80%|████████  | 4/5 [00:35<00:07,  7.17s/it]#015[Epoch 5] training: accuracy=0.592: 100%|██████████| 5/5 [00:35<00:00,  7.16s/it]#015[Epoch 5] training: accuracy=0.592: 100%|██████████| 5/5 [00:35<00:00,  7.17s/it]
# 2020-03-31 20:06:01,396 sagemaker-containers INFO     Reporting training SUCCESS
# 0 S root        605     88  0  80   0 -  1126 -      20:09 ?        00:00:00 /bin/sh -c ps -elf | grep "agremote"
# 0 S root        615    605  0  80   0 -  3247 -      20:09 ?        00:00:00 grep agremote
#
# Worker algo-2 exiting: training not started in 300 seconds.
# Host rank 1 exit.
# 2020-03-31 20:09:20,458 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-03-31 20:09:28 Uploading - Uploading generated training model
# 2020-03-31 20:09:28 Completed - Training job completed
# Training seconds: 876
# Billable seconds: 876
